# %% [markdown]
# <h2 align="center">EE1103 Numerical Methods</h2>
# <h3 align="center">Assignment 6</h3>
# <h3 align="center">Rajat Vadiraj Dwaraknath - EE16B033</h3>
#
# ---
# We first import numpy and matplotlib using pylab, and increase the size of the plots.

# %%
# Importing matplotlib and numpy directly
# Python 2.7
# %pylab inline
rcParams['figure.figsize'] = 12, 9 # Increase size of plots
rcParams['font.size'] = 20 # Increase font size in plots
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plotData(s):
    """
    Function to plot the data in a text file assuming it contains the solution to a system of differential equations.
    The first column is assumed to contain the time instants and the successive columns are assumed to contain the values
    of the states at those time instants. Any number of states can be present.
    """
    
    plt = matplotlib.pyplot
    
    # Open the file
    fo = open(s, 'r')

    # Read lines ignoring those that begin with '#'
    lines = fo.read().split("\n")[:-1]
    lines = [x.strip() for x in lines if x[0] != '#']

    # Close the file
    fo.close()

    # List of time instants
    t = []

    # List of state vectors
    states = []

    for i in lines:
        
        # Separate the columns
        values = i.split("\t")

        # First column contains time instants
        t.append(float(values[0]))

        # Add each successive column as a new state in the state vector
        states.append([float(i) for i in values[1:]])

    # Plot the data
    plt.plot(t,states)
    plt.xlabel("Time")
    plt.ylabel("States")
    plt.title(s+" States vs time")
    plt.legend(["State "+str(i) for i in range(1,len(states)+1,1)])
    plt.show()

# %% [markdown]
# ###  Answers to the questions
# **Please run make before running this notebook as the graphs cannot be plotted without the text files generated by make.**
# #### 1 (a)
# The differential equation is a first order ODE which can be solved using the RK4 method. The plot of the solution is shown below:

# %%
plotData("F1a.txt")

# %% [markdown]
# #### 1 (b)
# The differential equation is a first order ODE which can be solved using the RK4 method. The plot of the solution is shown below:

# %%
plotData("F1b.txt")

# %% [markdown]
# #### 2
# The question has a system of two first order ODEs which can be solved using the RK4 method by using a vector of state variables $\textbf{Y}$ in place of the single state variable $y$. The plot of the solution is shown below:

# %%
plotData("F2.txt")
